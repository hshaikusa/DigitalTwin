# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Hashim\\GitHub\\DigitalTwin\\code\\utils'

# %% [markdown]
# * environment used
# * yolo8                 *  C:\ProgramData\anaconda3\envs\yolo8

# %%
# !conda info --envs |find "*"
# Out:
# llm                   *  C:\ProgramData\anaconda3\envs\llm

# %%
df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_1_DTRF_LiDAR_csv.csv")

# %%
df[df['DTRF_1']==1]
# Out:
#           id       left        top      right     bottom  row_index  \
# 0      53799 -75.150056  39.951883 -75.150046  39.951873        122
# 1      53800 -75.150056  39.951873 -75.150046  39.951863        123
# 2      53797 -75.150056  39.951903 -75.150046  39.951893        120
# 3      53798 -75.150056  39.951893 -75.150046  39.951883        121
# 4      53799 -75.150056  39.951883 -75.150046  39.951873        122
# ...      ...        ...        ...        ...        ...        ...
# 10284  61286 -75.149756  39.952613 -75.149746  39.952603         49
# 10285  61287 -75.149756  39.952603 -75.149746  39.952593         50
# 10286  61288 -75.149756  39.952593 -75.149746  39.952583         51
# 10287  61539 -75.149746  39.952603 -75.149736  39.952593         50
# 10288  61540 -75.149746  39.952593 -75.149736  39.952583         51
#
#        col_index  DTRF_1  LIDAR_1
# 0            213     1.0      1.0
# 1            213     1.0      1.0
# 2            213     1.0      1.0
# 3            213     1.0      1.0
# 4            213     1.0      1.0
# ...          ...     ...      ...
# 10284        243     1.0      NaN
# 10285        243     1.0      NaN
# 10286        243     1.0      NaN
# 10287        244     1.0      NaN
# 10288        244     1.0      NaN
#
# [8400 rows x 9 columns]

# %%
df[df['LIDAR_1']==1]
# Out:
#          id       left        top      right     bottom  row_index  col_index  \
# 0     53799 -75.150056  39.951883 -75.150046  39.951873        122        213
# 1     53800 -75.150056  39.951873 -75.150046  39.951863        123        213
# 2     53797 -75.150056  39.951903 -75.150046  39.951893        120        213
# 3     53798 -75.150056  39.951893 -75.150046  39.951883        121        213
# 4     53799 -75.150056  39.951883 -75.150046  39.951873        122        213
# ...     ...        ...        ...        ...        ...        ...        ...
# 6590  51010 -75.150166  39.952053 -75.150156  39.952043        105        202
# 6591  50757 -75.150176  39.952063 -75.150166  39.952053        104        201
# 6592  50756 -75.150176  39.952073 -75.150166  39.952063        103        201
# 6593  50759 -75.150176  39.952043 -75.150166  39.952033        106        201
# 6594  50758 -75.150176  39.952053 -75.150166  39.952043        105        201
#
#       DTRF_1  LIDAR_1
# 0        1.0      1.0
# 1        1.0      1.0
# 2        1.0      1.0
# 3        1.0      1.0
# 4        1.0      1.0
# ...      ...      ...
# 6590     NaN      1.0
# 6591     NaN      1.0
# 6592     NaN      1.0
# 6593     NaN      1.0
# 6594     NaN      1.0
#
# [6595 rows x 9 columns]

# %%
df[(df['LIDAR_1']==1) & (df['DTRF_1']==1)]
# Out:
#          id       left        top      right     bottom  row_index  col_index  \
# 0     53799 -75.150056  39.951883 -75.150046  39.951873        122        213
# 1     53800 -75.150056  39.951873 -75.150046  39.951863        123        213
# 2     53797 -75.150056  39.951903 -75.150046  39.951893        120        213
# 3     53798 -75.150056  39.951893 -75.150046  39.951883        121        213
# 4     53799 -75.150056  39.951883 -75.150046  39.951873        122        213
# ...     ...        ...        ...        ...        ...        ...        ...
# 6577  15938 -75.151556  39.952493 -75.151546  39.952483         61         63
# 6578  15939 -75.151556  39.952483 -75.151546  39.952473         62         63
# 6579  50253 -75.150196  39.952063 -75.150186  39.952053        104        199
# 6580  50504 -75.150186  39.952073 -75.150176  39.952063        103        200
# 6581  50505 -75.150186  39.952063 -75.150176  39.952053        104        200
#
#       DTRF_1  LIDAR_1
# 0        1.0      1.0
# 1        1.0      1.0
# 2        1.0      1.0
# 3        1.0      1.0
# 4        1.0      1.0
# ...      ...      ...
# 6577     1.0      1.0
# 6578     1.0      1.0
# 6579     1.0      1.0
# 6580     1.0      1.0
# 6581     1.0      1.0
#
# [4706 rows x 9 columns]

# %%
df[(df['LIDAR_1']==1) | (df['DTRF_1']==1)]
# Out:
#           id       left        top      right     bottom  row_index  \
# 0      53799 -75.150056  39.951883 -75.150046  39.951873        122
# 1      53800 -75.150056  39.951873 -75.150046  39.951863        123
# 2      53797 -75.150056  39.951903 -75.150046  39.951893        120
# 3      53798 -75.150056  39.951893 -75.150046  39.951883        121
# 4      53799 -75.150056  39.951883 -75.150046  39.951873        122
# ...      ...        ...        ...        ...        ...        ...
# 10284  61286 -75.149756  39.952613 -75.149746  39.952603         49
# 10285  61287 -75.149756  39.952603 -75.149746  39.952593         50
# 10286  61288 -75.149756  39.952593 -75.149746  39.952583         51
# 10287  61539 -75.149746  39.952603 -75.149736  39.952593         50
# 10288  61540 -75.149746  39.952593 -75.149736  39.952583         51
#
#        col_index  DTRF_1  LIDAR_1
# 0            213     1.0      1.0
# 1            213     1.0      1.0
# 2            213     1.0      1.0
# 3            213     1.0      1.0
# 4            213     1.0      1.0
# ...          ...     ...      ...
# 10284        243     1.0      NaN
# 10285        243     1.0      NaN
# 10286        243     1.0      NaN
# 10287        244     1.0      NaN
# 10288        244     1.0      NaN
#
# [10289 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_1_DTRF_LiDAR_csv.csv")


# Filter data for campaigns A and B
campaign_a = df[df['DTRF_1'] == 1]
campaign_b = df[df['LIDAR_1'] == 1]
campaign_a_or_b = df[(df['LIDAR_1']==1) | (df['DTRF_1']==1)]
campaign_a_and_b = df[(df['LIDAR_1']==1) & (df['DTRF_1']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))


vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))
v1.get_patch_by_id("11").set_color("green")

# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR")

plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_1_DTRF_LiDAR_results.png")
plt.show()
# Out:
# DTRF = 8197
# LiDAR = 6372
# DTRF OR LiDAR = 10056
# DTRF AND LiDAR = 4513
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 70.8255%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_2_DTRF_LiDAR_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_2'] == 1]
campaign_b = df[df['LIDAR_2'] == 1]
campaign_a_or_b = df[(df['LIDAR_2']==1) | (df['DTRF_2']==1)]
campaign_a_and_b = df[(df['LIDAR_2']==1) & (df['DTRF_2']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))


vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)


v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))
v1.get_patch_by_id("11").set_color("green")

# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 

plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_2_DTRF_LiDAR_results.png")
plt.show()
# Out:
# DTRF = 6271
# LiDAR = 5648
# DTRF OR LiDAR = 8333
# DTRF AND LiDAR = 3586
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 63.4915%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_3_DTRF_LiDAR_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_3'] == 1]
campaign_b = df[df['LIDAR_3'] == 1]
campaign_a_or_b = df[(df['LIDAR_3']==1) | (df['DTRF_3']==1)]
campaign_a_and_b = df[(df['LIDAR_3']==1) & (df['DTRF_3']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))



vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))

v1.get_patch_by_id("11").set_color("green")

# lbl = v1.get_label_by_id('01')
# x,y = lbl.get_position()
# lbl.set_position((x+0.5,y))
# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 


plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_3_DTRF_LiDAR_results.png")
plt.show()
# Out:
# DTRF = 534
# LiDAR = 240
# DTRF OR LiDAR = 548
# DTRF AND LiDAR = 226
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 94.1667%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_4_DTRF_LiDAR_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_4'] == 1]
campaign_b = df[df['LIDAR_4'] == 1]
campaign_a_or_b = df[(df['LIDAR_4']==1) | (df['DTRF_4']==1)]
campaign_a_and_b = df[(df['LIDAR_4']==1) & (df['DTRF_4']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))



vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))

v1.get_patch_by_id("11").set_color("green")

# lbl = v1.get_label_by_id('01')
# x,y = lbl.get_position()
# lbl.set_position((x+0.5,y))
# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 


plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_4_DTRF_LiDAR_results.png")
plt.show()
# Out:
# DTRF = 2258
# LiDAR = 1891
# DTRF OR LiDAR = 2610
# DTRF AND LiDAR = 1539
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 81.3855%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_5_DTRF_LiDAR_2_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_5'] == 1]
campaign_b = df[df['LIDAR_5'] == 1]
campaign_a_or_b = df[(df['LIDAR_5']==1) | (df['DTRF_5']==1)]
campaign_a_and_b = df[(df['LIDAR_5']==1) & (df['DTRF_5']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))



vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))

v1.get_patch_by_id("11").set_color("green")

# lbl = v1.get_label_by_id('01')
# x,y = lbl.get_position()
# lbl.set_position((x+0.5,y))
# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 


plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_5_DTRF_LiDAR_2_results.png")
plt.show()
# Out:
# DTRF = 2105
# LiDAR = 1065
# DTRF OR LiDAR = 2518
# DTRF AND LiDAR = 652
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 61.2207%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_6_DTRF_LiDAR_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_6'] == 1]
campaign_b = df[df['LIDAR_6'] == 1]
campaign_a_or_b = df[(df['LIDAR_6']==1) | (df['DTRF_6']==1)]
campaign_a_and_b = df[(df['LIDAR_6']==1) & (df['DTRF_6']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))



vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))

v1.get_patch_by_id("11").set_color("green")

# lbl = v1.get_label_by_id('01')
# x,y = lbl.get_position()
# lbl.set_position((x+0.5,y))
# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 


plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_6_DTRF_LiDAR_results.png")
# Out:
# DTRF = 6566
# LiDAR = 6499
# DTRF OR LiDAR = 8481
# DTRF AND LiDAR = 4584
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 70.5339%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

df = pd.read_csv(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_7_DTRF_LiDAR_csv.csv")

# Filter data for campaigns A and B
campaign_a = df[df['DTRF_7'] == 1]
campaign_b = df[df['LIDAR_7'] == 1]
campaign_a_or_b = df[(df['LIDAR_7']==1) | (df['DTRF_7']==1)]
campaign_a_and_b = df[(df['LIDAR_7']==1) & (df['DTRF_7']==1)]

# Create sets from client IDs
dtrf = set(campaign_a['id'])
lidar = set(campaign_b['id'])
dtrf_or_lidar = set(campaign_a_or_b['id'])
dtrf_and_lidar = set(campaign_a_and_b['id'])

print("DTRF = {}\nLiDAR = {}\nDTRF OR LiDAR = {}\nDTRF AND LiDAR = {}".format(len(dtrf),len(lidar), len(dtrf_or_lidar), len(dtrf_and_lidar)))
print("\n\nOut of the LiDAR reprsented vegetation, DTRF is representing = {:.4f}%".format(len(dtrf_and_lidar)/len(lidar) * 100))
# Plot the Venn diagram
plt.figure(figsize=(8, 8))
# venn2([dtrf, lidar], ('DTRF', 'LiDAR'))



vc=venn2_circles(subsets= [dtrf, lidar],linestyle="dashed",linewidth=2)
vc[0].set_lw(8.0)
vc[0].set_ls('dashed')
vc[0].set_color('limegreen')
vc[0].set_alpha(0.7)

vc[1].set_lw(8.0)
vc[1].set_ls('dashed')
vc[1].set_color('yellow')
vc[1].set_alpha(0.7)

v1 = venn2(
    subsets= [dtrf, lidar],
    set_labels=['DTRF', 'LiDAR'],
    set_colors=['limegreen', 'yellow'], alpha=0.7,
    #subset_label_formatter=lambda x: f"{(x/len(dtrf_lidar)):1.0%}"
    subset_label_formatter=lambda x: str(x) + "\n(" + f"{(x/len(dtrf_or_lidar)):1.0%}" + ")"
)

v1.get_label_by_id('10').set_text('Foliage from \nDT\n{:.2f}%'.format(len(dtrf-lidar)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('01').set_text('Folaige from \nLiDAR\n{:.2f}%'.format(len(lidar-dtrf)/len(dtrf_or_lidar) * 100))
v1.get_label_by_id('11').set_text('Folaige from \nDT & LiDAR = {:.2f}%\n\n\n Out of LiDAR, \nDTRF represents\n\n{:.2f}%  foliage'.format((len(dtrf&lidar)/len(dtrf_or_lidar) * 100),len(dtrf_and_lidar)/len(lidar) * 100))

v1.get_patch_by_id("11").set_color("green")

# lbl = v1.get_label_by_id('01')
# x,y = lbl.get_position()
# lbl.set_position((x+0.5,y))
# title of the venn diagram 
plt.title("\nFoliage Comparision measured from DT vs LiDAR") 


plt.savefig(r"C:\Users\Hashim\GitHub\DigitalTwin\code\ultralytics\examples\datasets\Grid_SubSample_7_DTRF_LiDAR_results.png")
# Out:
# DTRF = 7351
# LiDAR = 8609
# DTRF OR LiDAR = 10362
# DTRF AND LiDAR = 5598
#
#
# Out of the LiDAR reprsented vegetation, DTRF is representing = 65.0250%
