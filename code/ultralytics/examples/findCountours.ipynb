# %%
import cv2
import matplotlib.pyplot as plt
#test=r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-948932_-75-152446_IonicStreet_30_png.rf.f09c3526be654cbf10242043ff0263f7_bin.jpg"
test=r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-5\test\satellite_images_bin\satellite_39.94649482638637_-75.14479446988959_DockStreet_67_bin.png"

im_gray = cv2.imread(test,0)
im_color=cv2.imread(test,1)
contours, hierarchy = cv2.findContours(im_gray,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
cv2.drawContours(im_color, contours, -1, (0,255,0), 3)
im = cv2.cvtColor(im_color, cv2.COLOR_BGR2GRAY)
# if you plot im now you will see grey contours not white
im[im!=0]=255

# %%
import os
import glob
HOME = os.getcwd()
for image_path in glob.glob(os.path.join(HOME,"datasets\\vegetation-yolo8-3\\test\\images","*_bin.jpg"))[:]:
    print(image_path)
# Out:
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-948932_-75-152446_IonicStreet_30_png.rf.f09c3526be654cbf10242043ff0263f7_bin.jpg
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-94931349740212_-75-14567243066136_ElbowLane_90_png.rf.2f1bc294e304abb09c05aa349f7fb1be_bin.jpg
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-949908111274105_-75-14189902030094_MarketStreet_21_png.rf.ac42ccc995b932fbb0410fb1d58435ae_bin.jpg
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-95003459983976_-75-14733556919555_South4thStreet_6_png.rf.d202b88c04b2cfb7280b1ac9b9544d89_bin.jpg
# ...

# %%
# Let's load a simple image with 3 black squares 
image = cv2.imread(test) 
# cv2.waitKey(0) 
  
# Grayscale 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
  
# Find Canny edges 
edged = cv2.Canny(gray, 30, 200) 
# cv2.waitKey(0) 
  
# Finding Contours 
# Use a copy of the image e.g. edged.copy() 
# since findContours alters the image 
contours, hierarchy = cv2.findContours(edged,  
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) 

#satellite_39.94649482638637_-75.14479446988959_DockStreet_67_bin.png
#orig = r'c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-3\test\images\satellite_39-948932_-75-152446_IonicStreet_30_png.rf.f09c3526be654cbf10242043ff0263f7.jpg'
orig = r'C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-5\test\satellite_images\satellite_39.94649482638637_-75.14479446988959_DockStreet_67.png'
plt.imshow(cv2.imread(orig))
plt.title("Sample Original Image")
plt.show()
#plt.imshow(cv2.imread(r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\runs\segment\predict11\satellite_39.948932_-75.152446_IonicStreet_30.png"))
plt.imshow(cv2.imread(r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\runs\segment\predict11\satellite_39.94649482638637_-75.14479446988959_DockStreet_67.png"))
plt.title("Original Image after foliage/vegetation detection")
plt.show
#cv2.imshow('Canny Edges After Contouring', edged)
plt.imshow(edged)
plt.title("Canny Edges After Contouring - binary  image")
plt.show()
# cv2.waitKey(0) 

# img = cv2.imread('path_to_image')
# plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
# plt.show()


print("Number of Contours found = " + str(len(contours))) 
  
# Draw all contours 
# -1 signifies drawing all contours 
cv2.drawContours(image, contours, -1, (0, 255, 0), 3) 
plt.title('Contours')
plt.imshow(image)
plt.savefig("satellite_39.94649482638637_-75.14479446988959_DockStreet_67_contours.png")
# Out:
# Number of Contours found = 3

# %%
# Python code to find the co-ordinates of 
# the contours detected in an image. 
import numpy as np 
import cv2 

# Reading image 
font = cv2.FONT_HERSHEY_COMPLEX 
img2 = cv2.imread(test, cv2.IMREAD_COLOR) 

# Reading same image in another 
# variable and converting to gray scale. 
img = cv2.imread(test, cv2.IMREAD_GRAYSCALE) 

# Converting image to a binary image 
# ( black and white only image). 
_, threshold = cv2.threshold(img, 110, 255, cv2.THRESH_BINARY) 

# Detecting contours in image. 
contours, _= cv2.findContours(threshold, cv2.RETR_EXTERNAL, 
							cv2.CHAIN_APPROX_SIMPLE) 

# Going through every contours found in the image. 
for cnt in contours :
    
	approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True) 
    
	# draws boundary of contours. 
	cv2.drawContours(img2, [approx], 0, (0, 0, 255), 2) 
    
	# Used to flatted the array containing 
	# the co-ordinates of the vertices. 
	n = approx.ravel() 
	i = 0
    
	for j in n : 
		if(i % 2 == 0): 
			x = n[i] 
			y = n[i + 1] 
			# String containing the co-ordinates. 
			string = str(x) + " " + str(y)
			print(string) 

			if(i == 0): 
				# text on topmost co-ordinate. 
				cv2.putText(img2, "Arrow tip", (x, y), 
								font, 0.3, (255, 0, 0)) 
			else: 
				# text on remaining co-ordinates. 
				cv2.putText(img2, string, (x, y), 
						font, 0.3, (0, 255, 0)) 
		i = i + 1

# Showing the final image. 
#cv2.imshow('image2', img2)
plt.title('Contour with Vertices')
plt.imshow(img2)
plt.savefig("satellite_39.94649482638637_-75.14479446988959_DockStreet_67_contours_vertices.png")

# # Exiting the window if 'q' is pressed on the keyboard. 
# if cv2.waitKey(0) & 0xFF == ord('q'): 
# 	cv2.destroyAllWindows()
# Out:
# 287 176
# 241 164
# 189 167
# 165 196
# 98 218
# 70 269
# 54 233
# 8 228
# 4 287
# 287 287
# 229 49
# 216 66
# 216 98
# 237 99
# 241 103
# 258 103
# 265 99
# 268 73
# 262 49
# 43 9
# 36 29
# 36 63
# 39 68
# 67 75
# 97 75
# 113 71
# 116 48
# 108 39
# 107 21
# 100 11
# 87 9
# 74 13
# 62 4
# 49 4

# %%
os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[2]
# Out:
# '-75-15154265627747'

# %%
os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1]
# Out:
# '39-95346436428708'

# %%
pos=os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1].index('-', os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1].index('-')) 
x = os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1][:pos] + '.' + os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1][pos+1:]
float(x)
# Out:
# 39.95346436428708

# %%
cent_lat_lon_det = r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\SamplePHil_DWNTWN_1_points_on_streets_with_geoInfo1.csv"
df_latlon_det = pd.read_csv(cent_lat_lon_det)
df_latlon_det[df_latlon_det['name'] == 'Ionic Street']
# Out:
#     fid    osm_id          name  highway       angle     xcoord     ycoord
# 30    9  12116719  Ionic Street  service  276.573449 -75.152446  39.948932
# 31    9  12116719  Ionic Street  service  276.573449 -75.152744  39.948966
# 32    9  12116719  Ionic Street  service  276.573449 -75.153042  39.949001
# 33    9  12116719  Ionic Street  service  276.573449 -75.153340  39.949035
# 34    9  12116719  Ionic Street  service  276.573449 -75.153638  39.949069
# 35    9  12116719  Ionic Street  service  276.573449 -75.153936  39.949104
# 36   10  12116728  Ionic Street  service  277.095754 -75.142571  39.947702
# 37   10  12116728  Ionic Street  service  277.115241 -75.142869  39.947740
# 38   10  12116728  Ionic Street  service  277.115241 -75.143166  39.947777
# 39   10  12116728  Ionic Street  service  277.115241 -75.143464  39.947814
# 40   10  12116728  Ionic Street  service  277.115241 -75.143762  39.947851
# ...

# %%
# Python code to find the co-ordinates of 
# the contours detected in an image. 

import os
import glob
import numpy as np 
import cv2
import pandas as pd

HOME = os.getcwd()
cols = ['StreetName', 'index', 'cent_lat', 'cent_lon', 'Xx_vertices', 'Yy_vertices','XxYy_vertices']
df = pd.DataFrame(columns=cols)
g_stnames = []
g_indices = []
g_Xx_vertices = []
g_Yy_vertices = []
g_XxYy_vertices = []
g_cent_lat = []
g_cent_lon = []
for image_path in glob.glob(os.path.join(HOME,"datasets\\vegetation-yolo8-3\\test\\images","*_bin.png"))[:]:
    print(image_path)
    stname = os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[3]

    pos=os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[2].index('-', os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[2].index('-') + 1) 
    cent_lat = os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[2][:pos] + '.' + os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[2][pos + 1:]

    cent_lat
    print(cent_lat)    

    pos=os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1].index('-', os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1].index('-')) 
    cent_lon = os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1][:pos] + '.' + os.path.splitext(os.path.basename(image_path))[0].split('.')[0].split('_')[1][pos+1:]

    cent_lon
    print(cent_lon)        
   
    # Reading image 
    font = cv2.FONT_HERSHEY_COMPLEX 
    img2 = cv2.imread(image_path, cv2.IMREAD_COLOR) 
    
    # Reading same image in another 
    # variable and converting to gray scale. 
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) 
    
    # Converting image to a binary image 
    # ( black and white only image). 
    _, threshold = cv2.threshold(img, 110, 255, cv2.THRESH_BINARY) 
    
    # Detecting contours in image. 
    contours, _= cv2.findContours(threshold, cv2.RETR_TREE, 
    							cv2.CHAIN_APPROX_SIMPLE) 
    
    # Going through every contours found in the image.
    index = 0
    num_contours = len(contours)
    for cnt in contours :
    	Xx=[]
    	Yy=[]
    	XxYy = []
    	approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True) 
        
    	# draws boundary of contours. 
    	cv2.drawContours(img2, [approx], 0, (0, 0, 255), 5) 
        
    	# Used to flatted the array containing 
    	# the co-ordinates of the vertices. 
    	n = approx.ravel() 
    	i = 0
    	print("Contours {}/{}".format(index,num_contours),"--"*20)        
    	for j in n : 
    		if(i % 2 == 0): 
    			x = n[i] 
    			y = n[i + 1] 
    			# String containing the co-ordinates. 
    			string = str(x) + " " + str(y)
    			Xx.append(x)
    			Yy.append(y)
    			XxYy.append([x,y])
    			#print(string) 
    
    			if(i == 0): 
    				# text on topmost co-ordinate. 
    				cv2.putText(img2, "Arrow tip", (x, y), 
    								font, 0.5, (255, 0, 0)) 
    			else: 
    				# text on remaining co-ordinates. 
    				cv2.putText(img2, string, (x, y), 
    						font, 0.5, (0, 255, 0)) 

    		i = i + 1
    	g_stnames.append(stname)
    	g_indices.append(index)
    	g_Xx_vertices.append(Xx)
    	g_Yy_vertices.append(Yy)
    	g_XxYy_vertices.append(XxYy)        
    	g_cent_lat.append(float(cent_lat))     
    	g_cent_lon.append(float(cent_lon))

    	plt.title('image{}'.format(stname))
    	plt.imshow(img2)
    	index = index+1        
df['StreetName'] = g_stnames
df['index'] = g_indices
df['Xx_vertices'] = g_Xx_vertices
df['Yy_vertices'] = g_Yy_vertices
df['XxYy_vertices'] = g_XxYy_vertices
df['cent_lat'] = g_cent_lat
df['cent_lon'] = g_cent_lon

df.to_csv("{}/datasets/Ionic_street_vertices.csv".format(HOME))
# Out:
# 1

# %%
path = r"C:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-5\test\satellite_images_bin\satellite_39.94549015542814_-75.14174565070432_SouthChristopherColumbusBoulevard_662_bin.png"
print(os.path.splitext(os.path.basename(path))[0])
os.path.splitext(os.path.basename(path))[0].split('_')
# Out:
# satellite_39.94549015542814_-75.14174565070432_SouthChristopherColumbusBoulevard_662_bin
# ['satellite',
#  '39.94549015542814',
#  '-75.14174565070432',
#  'SouthChristopherColumbusBoulevard',
#  '662',
#  'bin']

# %% [markdown]
# ## Looping over all the binary images to get the contours and vertices

# %%
# Python code to find the co-ordinates of 
# the contours detected in an image. 

import os
import glob
import numpy as np 
import cv2
import pandas as pd

HOME = os.getcwd()
cols = ['StreetName', 'index', 'cent_lat', 'cent_lon', 'Xx_vertices', 'Yy_vertices','XxYy_vertices']
df = pd.DataFrame(columns=cols)
g_stnames = []
g_indices = []
g_Xx_vertices = []
g_Yy_vertices = []
g_XxYy_vertices = []
g_cent_lat = []
g_cent_lon = []
image_count = 0
for image_path in glob.glob(os.path.join(HOME,"datasets\\vegetation-yolo8-5\\test\\satellite_images_bin","*_bin.png"))[:]:
    print(image_path)
    stname = os.path.splitext(os.path.basename(image_path))[0].split('_')[3]

    cent_lat = (float(os.path.splitext(os.path.basename(image_path))[0].split('_')[1]))
    cent_lon = (float(os.path.splitext(os.path.basename(image_path))[0].split('_')[2]))
    
    # Reading image 
    font = cv2.FONT_HERSHEY_COMPLEX 
    img2 = cv2.imread(image_path, cv2.IMREAD_COLOR) 
    
    # Reading same image in another 
    # variable and converting to gray scale. 
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) 
    
    # Converting image to a binary image 
    # ( black and white only image). 
    _, threshold = cv2.threshold(img, 110, 255, cv2.THRESH_BINARY) 
    
    # Detecting contours in image. 
    contours, _= cv2.findContours(threshold, cv2.RETR_TREE, 
    							cv2.CHAIN_APPROX_SIMPLE) 
    
    # Going through every contours found in the image.
    index = 0
    num_contours = len(contours)
    for cnt in contours :
    	Xx=[]
    	Yy=[]
    	XxYy = []
    	# cent_lat = []
    	# cent_lon = []
    	approx = cv2.approxPolyDP(cnt, 0.009 * cv2.arcLength(cnt, True), True) 
        
    	# draws boundary of contours. 
    	cv2.drawContours(img2, [approx], 0, (0, 0, 255), 5) 
        
    	# Used to flatted the array containing 
    	# the co-ordinates of the vertices. 
    	n = approx.ravel() 
    	i = 0
    	print("Contours {}/{}".format(index,num_contours),"--"*20)        
    	for j in n : 
    		if(i % 2 == 0): 
    			x = n[i] 
    			y = n[i + 1] 
    			# String containing the co-ordinates. 
    			string = str(x) + " " + str(y)
    			Xx.append(x)
    			Yy.append(y)
    			XxYy.append([x,y])
    			# cent_lat.append(float(os.path.splitext(os.path.basename(image_path))[0].split('_')[1]))

    			# cent_lon.append(float(os.path.splitext(os.path.basename(image_path))[0].split('_')[2]))      
                   
    			#print(string) 
    
    			if(i == 0): 
    				# text on topmost co-ordinate. 
    				cv2.putText(img2, "Arrow tip", (x, y), 
    								font, 0.5, (255, 0, 0)) 
    			else: 
    				# text on remaining co-ordinates. 
    				cv2.putText(img2, string, (x, y), 
    						font, 0.5, (0, 255, 0)) 

    		i = i + 1
    	g_stnames.append(stname)
    	g_indices.append(index)
    	g_Xx_vertices.append(Xx)
    	g_Yy_vertices.append(Yy)
    	g_XxYy_vertices.append(XxYy)      
    	g_cent_lat.append(cent_lat)    
    	g_cent_lon.append(cent_lon)
    	print(cent_lat,"\n",cent_lon)
    	plt.title('image{}'.format(stname))
    	plt.imshow(img2)
    	index = index+1
        # image_count = image_count + 1
        # if image_Count == 100:
        #     break;
df['StreetName'] = g_stnames
df['index'] = g_indices
df['Xx_vertices'] = g_Xx_vertices
df['Yy_vertices'] = g_Yy_vertices
df['XxYy_vertices'] = g_XxYy_vertices
df['cent_lat'] = g_cent_lat
df['cent_lon'] = g_cent_lon

df.to_csv("{}/datasets/Philly_street_vertices.csv".format(HOME))
# Out:
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-5\test\satellite_images_bin\satellite_39.94549015542814_-75.14174565070432_SouthChristopherColumbusBoulevard_662_bin.png
# Contours 0/3 ----------------------------------------
# 39.94549015542814
#  -75.14174565070432
# Contours 1/3 ----------------------------------------
# 39.94549015542814
#  -75.14174565070432
# Contours 2/3 ----------------------------------------
# 39.94549015542814
#  -75.14174565070432
# c:\Users\Hashim\DIS-9901A\DigitalTwinData\code\ultralytics\examples\datasets\vegetation-yolo8-5\test\satellite_images_bin\satellite_39.945528059360605_-75.14197797734637_SouthChristopherColumbusBoulevard_863_bin.png
# Contours 0/4 ----------------------------------------
# 39.945528059360605
#  -75.14197797734637
# Contours 1/4 ----------------------------------------
# 39.945528059360605
#  -75.14197797734637
# Contours 2/4 ----------------------------------------
# ...
